# %% [markdown]
# # Ponderación

# %%
import pandas as pd

# %%
df_ine = pd.read_excel('input/ipc_producto_historico_julio2018.xlsx', header=3)

# %%
df_ine.head(2)
# Out:
#    DIVISIÓN  GRUPO  CLASE  SUBCLASE  PRODUCTO  PONDERACIÓN   GLOSA  \
# 0         1      1      1         1         1      0.20255   ARROZ
# 1         1      1      1         2         1      0.09708  HARINA
#
#    2014-01-01 00:00:00  2014-02-01 00:00:00  2014-03-01 00:00:00  \
# 0                99.95                99.98               100.76
# 1               101.06               101.65               102.79
#
#           ...           2018-03-01 00:00:00  2018-04-01 00:00:00  \
# 0         ...                        133.84               134.98
# 1         ...                        115.61               116.14
#
#    2018-05-01 00:00:00  2018-06-01 00:00:00  2018-07-01 00:00:00  \
# 0               134.08               133.72               133.66
# 1               116.17               116.65               115.41
#
#    2018-08-01 00:00:00  2018-09-01 00:00:00  2018-10-01 00:00:00  \
# 0                  NaN                  NaN                  NaN
# 1                  NaN                  NaN                  NaN
#
#    2018-11-01 00:00:00  2018-12-01 00:00:00
# 0                  NaN                  NaN
# 1                  NaN                  NaN
#
# [2 rows x 67 columns]

# %%
df_ine = df_ine[['PONDERACIÓN', 'GLOSA']]
df_ine.columns = [['Ponderacion', 'Producto_INE']]

# %%
len(df_ine)
# Out:
# 321

# %%
df_ine.loc[0:3,:]
# Out:
#   Ponderacion Producto_INE
# 0     0.20255        ARROZ
# 1     0.09708       HARINA
# 2     0.18699       CEREAL
# 3     2.09319          PAN

# %%
df_ine['Producto'] = df_ine['Producto_INE'].replace({'ARROZ':'Cereales',
                                                     'HARINA':'Harinas',
                                                     'CEREAL':'Cereales',
                                                     'PAN':'Pan',
                                                     'PASTAS':'Cereales',
                                                     'CARNE DE VACUNO':'Carnes',
                                                     'CARNE DE CERDO':'Carnes',
                                                     'CARNE DE PAVO':'Carnes',
                                                     'CARNE DE POLLO':'Carnes',
                                                     'CECINAS':'Carnes',
                                                     'HAMBURGUESA':'Carnes',
                                                     'LECHE EN POLVO':'Lacteos',
                                                     'LECHE LÍQUIDA':'Lacteos',
                                                     'LECHE CONSERVADA':'Lacteos',
                                                     'YOGHURT':'Lacteos',
                                                     'POSTRES LÁCTEOS':'Lacteos',
                                                     'QUESO':'Lacteos',
                                                     'HUEVOS':'Huevos',
                                                     'MANTEQUILLA':'Lacteos',
                                                     'MARGARINA':'Lacteos',
                                                     'ACEITE VEGETAL':'Aceite',
                                                     'MANZANA':'Frutas',
                                                     'NARANJA':'Frutas',
                                                     'PERA':'Frutas',
                                                     'PLÁTANO':'Frutas',
                                                     'FRUTAS DE ESTACIÓN':'Frutas',
                                                     'ACELGA Y ESPINACA':'Hortaliza',
                                                     'CEBOLLA Y CEBOLLÍN':'',
                                                     'LECHUGA':'Hortaliza',
                                                     'LIMÓN':'Frutas',
                                                     'PALTA':'Frutas',
                                                     'TOMATE':'Hortaliza',
                                                     'ZANAHORIA':'Hortaliza',
                                                     'ZAPALLO':'Hortaliza',
                                                     'ZAPALLO ITALIANO':'Hortaliza',
                                                     'VERDURAS DE ESTACIÓN':'Hortaliza',
                                                     'LEGUMBRES':'Legumbre',
                                                     'PAPA':'Hortaliza',
                                                     'AZÚCAR':'Azucar'})

# %%
productos = ['ARROZ','HARINA','CEREAL','PAN','PASTAS','CARNE DE VACUNO','CARNE DE CERDO','CARNE DE PAVO','CARNE DE POLLO','CECINAS','HAMBURGUESA','LECHE EN POLVO','LECHE LÍQUIDA',
            'LECHE CONSERVADA','YOGHURT','POSTRES LÁCTEOS','QUESO','HUEVOS','MANTEQUILLA','MARGARINA','ACEITE VEGETAL','MANZANA','NARANJA','PERA','PLÁTANO','FRUTAS DE ESTACIÓN','ACELGA Y ESPINACA',
            'CEBOLLA Y CEBOLLÍN','LECHUGA','LIMÓN','PALTA','TOMATE','ZANAHORIA','ZAPALLO','ZAPALLO ITALIANO','VERDURAS DE ESTACIÓN','LEGUMBRES','PAPA','AZÚCAR']

# %%
df_ine.head()
# Out:
#   Ponderacion Producto_INE  Producto
# 0     0.20255        ARROZ  Cereales
# 1     0.09708       HARINA   Harinas
# 2     0.18699       CEREAL  Cereales
# 3     2.09319          PAN       Pan
# 4     0.36509      GALLETA   GALLETA

# %%
productos = ['ARROZ','HARINA','CEREAL','PAN','PASTAS','CARNE DE VACUNO','CARNE DE CERDO','CARNE DE PAVO','CARNE DE POLLO','CECINAS','HAMBURGUESA','LECHE EN POLVO','LECHE LÍQUIDA',
            'LECHE CONSERVADA','YOGHURT','POSTRES LÁCTEOS','QUESO','HUEVOS','MANTEQUILLA','MARGARINA','ACEITE VEGETAL','MANZANA','NARANJA','PERA','PLÁTANO','FRUTAS DE ESTACIÓN','ACELGA Y ESPINACA',
            'CEBOLLA Y CEBOLLÍN','LECHUGA','LIMÓN','PALTA','TOMATE','ZANAHORIA','ZAPALLO','ZAPALLO ITALIANO','VERDURAS DE ESTACIÓN','LEGUMBRES','PAPA','AZÚCAR']

def cleanup(row):
    global productos
    if row['Producto_INE'].isin(productos).iloc[0] == False:
        return 'Mantener'
    else:
        return 'Desechar'

# %%
df_ine['Accion'] = df_ine.apply(cleanup, axis=1)

# %%
df_ine
# Out:
#     Ponderacion                                  Producto_INE  \
# 0       0.20255                                         ARROZ
# 1       0.09708                                        HARINA
# 2       0.18699                                        CEREAL
# 3       2.09319                                           PAN
# 4       0.36509                                       GALLETA
# 5       0.52671                       PRODUCTOS DE REPOSTERÍA
# 6       0.08030                      MASAS SALADAS PREPARADAS
# 7       0.07019                                         SNACK
# 8       0.28993                                        PASTAS
# 9       1.71291                               CARNE DE VACUNO
# 10      0.47526                                CARNE DE CERDO
# 11      0.10209                                 CARNE DE PAVO
# 12      0.96033                                CARNE DE POLLO
# 13      1.03909                                       CECINAS
# 14      0.09243                                   HAMBURGUESA
# 15      0.25941                                      PESCADOS
# 16      0.08985                                      MARISCOS
# 17      0.18753                          PESCADOS EN CONSERVA
# 18      0.03186                          MARISCOS EN CONSERVA
# 19      0.20152                                LECHE EN POLVO
# 20      0.48949                                 LECHE LÍQUIDA
# 21      0.06545                              LECHE CONSERVADA
# 22      0.41984                                       YOGHURT
# 23      0.06563                               POSTRES LÁCTEOS
# 24      0.74586                                         QUESO
# 25      0.33391                                        HUEVOS
# 26      0.12314                                   MANTEQUILLA
# 27      0.11859                                     MARGARINA
# 28      0.34550                                ACEITE VEGETAL
# 29      0.09812                                       MANZANA
# ..          ...                                           ...
# 291     0.06907                 MÁQUINA DE AFEITAR DESECHABLE
# 292     0.04045   ARTÍCULOS DIVERSOS PARA EL CUIDADO PERSONAL
# 293     0.03152                   BLOQUEADORES Y BRONCEADORES
# 294     0.23605                           COLONIAS Y PERFUMES
# 295     0.16724              DESODORANTES Y ANTITRANSPIRANTES
# 296     0.16213                    PRODUCTOS DE HIGIENE BUCAL
# 297     0.37394                               PAPEL HIGIÉNICO
# 298     0.09615                                         JABÓN
# 299     0.36327                           PAÑALES DESECHABLES
# 300     0.08505                 PROTECCIÓN HIGIÉNICA FEMENINA
# 301     0.24225                             SHAMPOO Y BÁLSAMO
# 302     0.20305                           CREMAS PARA LA PIEL
# 303     0.12160                       PRODUCTOS DE MAQUILLAJE
# 304     0.14949                          TINTURAS Y FIJADORES
# 305     0.16196                                         JOYAS
# 306     0.04785                             RELOJ  DE PULSERA
# 307     0.29367                             CARTERAS Y BOLSOS
# 308     0.05334                               COCHE PARA BEBÉ
# 309     0.05781                                 LENTES DE SOL
# 310     0.48124                           SEGURO DE AUTOMÓVIL
# 311     2.42126                              GASTO FINANCIERO
# 312     0.04235            SERVICIO DE EMISIÓN DE CERTIFICADO
# 313     0.04891                       SERVICIO DE FOTOCOPIADO
# 314     0.09976           MEMBRESÍA EN ASOCIACIÓN PROFESIONAL
# 315     0.09312                             SERVICIO NOTARIAL
# 316     0.30811                            SERVICIO FUNERARIO
# 317     0.02915           SERVICIOS DE ASESORAMIENTO JURÍDICO
# 318     0.06750      CUOTAS EN CENTROS DE PADRES Y APODERADOS
# 319     0.07087  SERVICIO DE RESIDENCIAS PARA ADULTOS MAYORES
# 320     0.09879                         SERVICIO DE SALA CUNA
#
#                                          Producto    Accion
# 0                                        Cereales  Mantener
# 1                                         Harinas  Mantener
# 2                                        Cereales  Mantener
# 3                                             Pan  Mantener
# 4                                         GALLETA  Desechar
# 5                         PRODUCTOS DE REPOSTERÍA  Desechar
# 6                        MASAS SALADAS PREPARADAS  Desechar
# 7                                           SNACK  Desechar
# 8                                        Cereales  Mantener
# 9                                          Carnes  Mantener
# 10                                         Carnes  Mantener
# 11                                         Carnes  Mantener
# 12                                         Carnes  Mantener
# 13                                         Carnes  Mantener
# 14                                         Carnes  Mantener
# 15                                       PESCADOS  Desechar
# 16                                       MARISCOS  Desechar
# 17                           PESCADOS EN CONSERVA  Desechar
# 18                           MARISCOS EN CONSERVA  Desechar
# 19                                        Lacteos  Mantener
# 20                                        Lacteos  Mantener
# 21                                        Lacteos  Mantener
# 22                                        Lacteos  Mantener
# 23                                        Lacteos  Mantener
# 24                                        Lacteos  Mantener
# 25                                         Huevos  Mantener
# 26                                        Lacteos  Mantener
# 27                                        Lacteos  Mantener
# 28                                         Aceite  Mantener
# 29                                         Frutas  Mantener
# ..                                            ...       ...
# 291                 MÁQUINA DE AFEITAR DESECHABLE  Desechar
# 292   ARTÍCULOS DIVERSOS PARA EL CUIDADO PERSONAL  Desechar
# 293                   BLOQUEADORES Y BRONCEADORES  Desechar
# 294                           COLONIAS Y PERFUMES  Desechar
# 295              DESODORANTES Y ANTITRANSPIRANTES  Desechar
# 296                    PRODUCTOS DE HIGIENE BUCAL  Desechar
# 297                               PAPEL HIGIÉNICO  Desechar
# 298                                         JABÓN  Desechar
# 299                           PAÑALES DESECHABLES  Desechar
# 300                 PROTECCIÓN HIGIÉNICA FEMENINA  Desechar
# 301                             SHAMPOO Y BÁLSAMO  Desechar
# 302                           CREMAS PARA LA PIEL  Desechar
# 303                       PRODUCTOS DE MAQUILLAJE  Desechar
# 304                          TINTURAS Y FIJADORES  Desechar
# 305                                         JOYAS  Desechar
# 306                             RELOJ  DE PULSERA  Desechar
# 307                             CARTERAS Y BOLSOS  Desechar
# 308                               COCHE PARA BEBÉ  Desechar
# 309                                 LENTES DE SOL  Desechar
# 310                           SEGURO DE AUTOMÓVIL  Desechar
# 311                              GASTO FINANCIERO  Desechar
# 312            SERVICIO DE EMISIÓN DE CERTIFICADO  Desechar
# 313                       SERVICIO DE FOTOCOPIADO  Desechar
# 314           MEMBRESÍA EN ASOCIACIÓN PROFESIONAL  Desechar
# 315                             SERVICIO NOTARIAL  Desechar
# 316                            SERVICIO FUNERARIO  Desechar
# 317           SERVICIOS DE ASESORAMIENTO JURÍDICO  Desechar
# 318      CUOTAS EN CENTROS DE PADRES Y APODERADOS  Desechar
# 319  SERVICIO DE RESIDENCIAS PARA ADULTOS MAYORES  Desechar
# 320                         SERVICIO DE SALA CUNA  Desechar
#
# [321 rows x 4 columns]

# %%
df_ine[df_ine['Accion'] == 'Mantener']
# Out:
#     Ponderacion Producto_INE Producto    Accion
# 0           NaN          NaN      NaN  Mantener
# 1           NaN          NaN      NaN  Mantener
# 2           NaN          NaN      NaN  Mantener
# 3           NaN          NaN      NaN  Mantener
# 4           NaN          NaN      NaN       NaN
# 5           NaN          NaN      NaN       NaN
# 6           NaN          NaN      NaN       NaN
# 7           NaN          NaN      NaN       NaN
# 8           NaN          NaN      NaN  Mantener
# 9           NaN          NaN      NaN  Mantener
# 10          NaN          NaN      NaN  Mantener
# 11          NaN          NaN      NaN  Mantener
# 12          NaN          NaN      NaN  Mantener
# 13          NaN          NaN      NaN  Mantener
# 14          NaN          NaN      NaN  Mantener
# 15          NaN          NaN      NaN       NaN
# 16          NaN          NaN      NaN       NaN
# 17          NaN          NaN      NaN       NaN
# 18          NaN          NaN      NaN       NaN
# 19          NaN          NaN      NaN  Mantener
# 20          NaN          NaN      NaN  Mantener
# 21          NaN          NaN      NaN  Mantener
# 22          NaN          NaN      NaN  Mantener
# 23          NaN          NaN      NaN  Mantener
# 24          NaN          NaN      NaN  Mantener
# 25          NaN          NaN      NaN  Mantener
# 26          NaN          NaN      NaN  Mantener
# 27          NaN          NaN      NaN  Mantener
# 28          NaN          NaN      NaN  Mantener
# 29          NaN          NaN      NaN  Mantener
# ..          ...          ...      ...       ...
# 291         NaN          NaN      NaN       NaN
# 292         NaN          NaN      NaN       NaN
# 293         NaN          NaN      NaN       NaN
# 294         NaN          NaN      NaN       NaN
# 295         NaN          NaN      NaN       NaN
# 296         NaN          NaN      NaN       NaN
# 297         NaN          NaN      NaN       NaN
# 298         NaN          NaN      NaN       NaN
# 299         NaN          NaN      NaN       NaN
# 300         NaN          NaN      NaN       NaN
# 301         NaN          NaN      NaN       NaN
# 302         NaN          NaN      NaN       NaN
# 303         NaN          NaN      NaN       NaN
# 304         NaN          NaN      NaN       NaN
# 305         NaN          NaN      NaN       NaN
# 306         NaN          NaN      NaN       NaN
# 307         NaN          NaN      NaN       NaN
# 308         NaN          NaN      NaN       NaN
# 309         NaN          NaN      NaN       NaN
# 310         NaN          NaN      NaN       NaN
# 311         NaN          NaN      NaN       NaN
# 312         NaN          NaN      NaN       NaN
# 313         NaN          NaN      NaN       NaN
# 314         NaN          NaN      NaN       NaN
# 315         NaN          NaN      NaN       NaN
# 316         NaN          NaN      NaN       NaN
# 317         NaN          NaN      NaN       NaN
# 318         NaN          NaN      NaN       NaN
# 319         NaN          NaN      NaN       NaN
# 320         NaN          NaN      NaN       NaN
#
# [321 rows x 4 columns]

# %%
df_ine.Producto_INE.isin(productos).iloc[0]
# Out:
# Producto_INE    True
# Name: 0, dtype: bool
